# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('results.csv')
df
# Out:
#                       epoch           train/box_loss           train/cls_loss  \
# 0                         1                  2.11940                  3.62280
# 1                         2                  1.77930                  2.56020
# 2                         3                  1.74780                  2.20070
# 3                         4                  1.69860                  1.93060
# 4                         5                  1.66260                  1.70770
# ..                      ...                      ...                      ...
# 95                       96                  0.90387                  0.38015
# 96                       97                  0.89921                  0.37664
# 97                       98                  0.89507                  0.37185
# 98                       99                  0.87777                  0.36873
# 99                      100                  0.88086                  0.36740
#
# ...

# %%
plt.plot(df['         train/cls_loss'])
plt.plot(df['           val/cls_loss'])
plt.legend(['train/cls_loss', 'val/cls_loss'])
plt.xlabel('epoch')
plt.ylabel('cls loss')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
